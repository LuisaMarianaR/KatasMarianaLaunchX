# %% [markdown]
# Capturas de los ejercicios de la Kata 10

# %%
import IPython.display as display
from PIL import Image
display.display(Image.open('error1.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=884x644 at 0x198C3C14850>

# %%
import IPython.display as display
from PIL import Image
display.display(Image.open('Error2.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=884x653 at 0x198C2DB2AD0>

# %%
import IPython.display as display
from PIL import Image
display.display(Image.open('Error3.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=884x470 at 0x198C2D76DD0>
