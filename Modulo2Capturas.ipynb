# %% [markdown]
# Pruebas de la Kata número 2

# %%
import IPython.display as display
from PIL import Image
display.display(Image.open('Kataenv.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=884x474 at 0x1D7BF8A2D10>

# %%
import IPython.display as display
from PIL import Image
display.display(Image.open('Katapaquete.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=884x474 at 0x1D7C1893670>
